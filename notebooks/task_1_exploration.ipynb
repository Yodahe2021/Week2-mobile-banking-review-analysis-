# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_raw = pd.read_csv("../data/raw/reviews_raw.csv")
df_raw.head()
# Out:
#   bank             app_name                            review  rating  \
# 0  CBE  CBE Mobile Banking                          CBE ይለያል።       5
# 1  CBE  CBE Mobile Banking                it's special for me       5
# 2  CBE  CBE Mobile Banking             Make it user friendly.       2
# 3  CBE  CBE Mobile Banking   maaliif daddafee install gaafata       3
# 4  CBE  CBE Mobile Banking                           good app       5
#
#          date       source
# 0  2025-11-29  google-play
# 1  2025-11-29  google-play
# 2  2025-11-29  google-play
# 3  2025-11-28  google-play
# 4  2025-11-28  google-play

# %%
df_raw.info()
df_raw.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10079 entries, 0 to 10078
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   bank      10079 non-null  object
#  1   app_name  10079 non-null  object
#  2   review    10072 non-null  object
#  3   rating    10079 non-null  int64
#  4   date      10079 non-null  object
#  5   source    10079 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 472.6+ KB
#              rating
# count  10079.000000
# mean       3.961306
# std        1.561306
# min        1.000000
# 25%        3.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %%
df_raw['rating'].value_counts().plot(kind='bar')
plt.title('Rating Distribution (Raw Data)')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# %%
df_raw['bank'].value_counts().plot(kind='bar')
plt.title('Review Count by Bank')
plt.show()
